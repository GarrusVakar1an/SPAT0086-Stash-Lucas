# %% [markdown]
# # Assignment 2: Lensing catalogues
# Author: Lucas D'Ascoli

# %% [markdown]
# ## Base imports
#
# Before starting anything, here are the base imports needed for this jupyter notebook:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import astropy

# %% [markdown]
# Similarly to the function we used in [Assignment 1](Assignment_1.ipynb), to get our data folder, we use:

# %%
Path = os.path.abspath(os.path.join(os.path.dirname('Assignment_2.ipynb'), '..', 'Data'))
print(Path)
# Out:
# c:\Users\Lucas\Documents\Python\SPAT0086-Stash-Lucas\Project_Root\Data

# %% [markdown]
# ## Main
#
# We are tasked to understand the catalog `q1_MER_morph_EDFN_w_score_4students.fits`, in particular, we are asked (quoted from the main class):
# - How many objects are present in that catalog?
# - How many columns does it contain? Are they all filled with values?
# - Do all columns contain sensible information for machine learning classification tasks?
# - Some lenses from `q1_lens_search_EDFN_4students.csv` are in that table. Which ones? Is it a problem?
# - What are the lens engine scores for the lenses? Plot their distribution.
# - Are all engines equivalent? Is there a methodology you can use to compare the performances of the different engines (you might have to wait the end of the ML lectures to answer that question).
